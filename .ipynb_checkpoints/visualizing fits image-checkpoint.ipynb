# %%
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from astropy.utils.data import download_file
image_file = download_file('http://data.astropy.org/tutorials/FITS-images/HorseHead.fits', cache=True )

# %%
from astropy.io import fits
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: /Users/sunil/.astropy/cache/download/py3/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
image_data=hdu_list[0].data

# %%
image_data.shape
# Out:
# (893, 891)

# %%
hdu_list.close()

# %%
image_data
# Out:
# array([[ 7201,  6642,  6642, ...,  9498,  9498, 10057],
#        [ 6642,  6363,  6642, ..., 10057, 10616, 10616],
#        [ 6922,  6642,  6922, ..., 10337, 11175, 10616],
#        ...,
#        [ 5412,  5132,  5412, ..., 13000, 12580, 12021],
#        [ 5796,  5517,  5796, ..., 12546, 12546, 11987],
#        [ 5796,  5796,  6076, ..., 11987, 12546, 12546]], dtype=int16)

# %%
image_header=fits.getheader(image_file, ext=1) # ext=0 also

# %%
image_data=fits.getdata(image_file)

# %%
plt.imshow(image_data)
plt.colorbar(orientation='horizontal')

# %%
print(type(image_data.flatten()))
# Out:
# <class 'numpy.ndarray'>

# %%
histogram = plt.hist(image_data.flatten(), bins='auto')

# %%
from matplotlib.colors import LogNorm

# %%
plt.imshow(image_data, norm=LogNorm())

# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
cbar.ax.set_yticklabels(['5,000','10,000','2*10^4'])
# Out:
# [Text(1, 0, '5,000'), Text(1, 0, '10,000'), Text(1, 0, '2*10^4')]

# %% [markdown]
# #

# %%
plt.imshow(image_data,)
cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
cbar.ax.set_yticklabels(['weak','mild','strong'])
# Out:
# [Text(1, 0, 'weak'), Text(1, 0, 'mild'), Text(1, 0, 'strong')]

# %%
outfile='test.fits'
hdu=fits.PrimaryHDU(image_data*0.01)
hdu.writeto(outfile,overwrite=True)
